# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## purpose of this notebook is to collect samples of data

# %% [markdown]
# # 1. day of burn yearly

# %%
import rasterio as rio

## reading one file for each band

path = '../data/dayofburn_yearly/Global_fire_atlas_day_of_burn_yearly_2003.tif'

with rio.open(path) as img :
    imgnp= img.read()
    imgmeta=img.meta

# %%
print(imgnp.shape)
# Out:
# (1, 31200, 81600)

# %%
## visualizing one file

plt.imshow(imgnp[0,:,:], cmap='hot')

# %% [markdown]
# # 2.1. Direction Monthly

# %%
import rasterio as rio

## reading one file for each band

path = '../data/direction/direction_monthly/Global_fire_atlas_direction_monthly_2004.tif'

with rio.open(path) as img :
    imgnp= img.read()
    imgmeta=img.meta

# %%
plt.imshow(imgnp[0,:,:], cmap='hot')

# %% [markdown]
# # 2.2. Direction Yearly

# %%
import rasterio as rio

## reading one file for each band

path = '../data/direction/direction_yearly/Global_fire_atlas_direction_yearly_2005.tif'

with rio.open(path) as img :
    imgnp= img.read()
    imgmeta=img.meta

# %%
plt.imshow(imgnp[0,:,:])

# %% [markdown]
# # 3.1 Duration Monthly

# %%
## reading one file for each band

path = '../data/duration_monthly/Global_fire_atlas_duration_monthly_2003.tif'

with rio.open(path) as img :
    imgnp= img.read()
    imgmeta=img.meta

plt.imshow(imgnp[0,:,:], cmap='hot')

# %% [markdown]
# # 4.1 Fireline Monthly

# %%
path = '../data/fireline/fireline_monthly/Global_fire_atlas_fire_line_monthly_2003.tif'

with rio.open(path) as img :
    imgnp= img.read()
    imgmeta=img.meta

plt.imshow(imgnp[0,:,:], cmap='hot')

# %% [markdown]
# # 4.2 Fireline Yearly

# %%
path = '../data/fireline/fireline_yearly/Global_fire_atlas_fire_line_yearly_2003.tif'

with rio.open(path) as img :
    imgnp= img.read()
    imgmeta=img.meta

plt.imshow(imgnp[0,:,:], cmap='hot')

# %% [markdown]
# # 5.1 Ignition Monthly

# %%
path = '../data/ignition/ignition_monthly/Global_fire_atlas_ignitions_monthly_2003.tif'

with rio.open(path) as img :
    imgnp= img.read()
    imgmeta=img.meta

plt.imshow(imgnp[0,:,:], cmap='hot')

# %% [markdown]
# # 6 Perimeter

# %%
import geopandas as gpd

path = '../data/perimeter/Global_fire_atlas_V1_perimeter_2003'
gdf = gpd.read_file(path)
gdf.head()
# Out:
#    fire_ID      lat      lon  size  perimeter  start_date  start_DOY  \
# 0        1  21.5312 -158.212  6.43      12.04  2003-07-20        201
# 1        2  20.6521 -156.258  0.21       1.85  2003-06-27        178
# 2        3  20.6396 -156.245  9.00      16.67  2003-07-08        189
# 3        4  20.5396 -156.668  1.50       7.41  2003-05-02        122
# 4        5  19.4229 -155.420  6.22      12.96  2003-02-25         56
#
#      end_date  end_DOY  duration  expansion  fire_line  speed  direction  \
# 0  2003-07-30      211        11       0.58       1.22   0.91          8
# 1  2003-06-27      178         1       0.21       0.46   0.46          0
# 2  2003-07-13      194         6       1.50       2.08   1.68          4
# 3  2003-05-11      131        10       0.15       0.32   0.86          4
# 4  2003-03-01       60         5       1.24       2.41   1.08          8
#
#   direction_s  landcover      landcover_s tile_ID  \
# 0   northwest         12        Croplands  h03v06
# ...

# %%
gdf.columns
# Out:
# Index(['fire_ID', 'lat', 'lon', 'size', 'perimeter', 'start_date', 'start_DOY',
#        'end_date', 'end_DOY', 'duration', 'expansion', 'fire_line', 'speed',
#        'direction', 'direction_s', 'landcover', 'landcover_s', 'tile_ID',
#        'geometry'],
#       dtype='object')

# %%
gdf.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # 7 Size

# %%
path = '../data/size_monthly/Global_fire_atlas_size_monthly_2003.tif'

with rio.open(path) as img :
    imgnp= img.read()
    imgmeta=img.meta

plt.imshow(imgnp[0,:,:], cmap='hot')

# %% [markdown]
# # 8.1 Speed monthly

# %%
path = '../data/speed/speed_monthly/Global_fire_atlas_speed_monthly_2003.tif'

with rio.open(path) as img :
    imgnp= img.read()
    imgmeta=img.meta

plt.imshow(imgnp[0,:,:], cmap='hot')

# %% [markdown]
# # 7.2 Speed Yearly

# %% [markdown]
# # 8.1 Spread Monthly

# %%
path = '../data/spread_monthly/Global_fire_atlas_spread_monthly_2003.tif'

import rasterio as rio

with rio.open(path) as img :
    imgnp= img.read()
    imgmeta=img.meta

plt.imshow(imgnp[0,:,:], cmap='hot')
